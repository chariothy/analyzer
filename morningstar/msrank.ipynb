# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import imp
import query
imp.reload(query)
from query import query_fund
import sys, os
import pandas as pd
from os import path
sys.path.append(path.dirname(path.dirname(os.getcwd())))
APP_NAME = 'msrank'
from utils import AnalyzerUtil
su = AnalyzerUtil(APP_NAME)

import msrank
imp.reload(msrank)
df = msrank.query_fund("b.name like '%800%'")
df = msrank.export_fund(df)
df
# Out:
# 2022-01-06 16:51:44,563 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2022-01-06 16:51:44,571 INFO sqlalchemy.engine.base.Engine {}
# 2022-01-06 16:51:44,603 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2022-01-06 16:51:44,606 INFO sqlalchemy.engine.base.Engine {}
# 2022-01-06 16:51:44,652 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2022-01-06 16:51:44,656 INFO sqlalchemy.engine.base.Engine {}
# 2022-01-06 16:51:44,702 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2022-01-06 16:51:44,706 INFO sqlalchemy.engine.base.Engine {}
# 2022-01-06 16:51:44,730 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# 2022-01-06 16:51:44,733 INFO sqlalchemy.engine.base.Engine {}
# 2022-01-06 16:51:44,778 INFO sqlalchemy.engine.base.Engine DESCRIBE `
# ...

# %%
import imp

from morningstar import msrank
imp.reload(msrank)
top_fund_df = msrank.query_fund()
rank_fund_df = msrank.rank_fund(top_fund_df)
rank_fund_group_df = rank_fund_df.groupby('cat_name')
# Out:
# 2022-01-29 11:25:21,104 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2022-01-29 11:25:21,108 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-01-29 11:25:21,133 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2022-01-29 11:25:21,138 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-01-29 11:25:21,175 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2022-01-29 11:25:21,176 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-01-29 11:25:21,226 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# ...

# %%
df = rank_fund_group_df.get_group('中盘平衡股票')
df
for label, fund in df.iterrows():
    print(label, fund['asset'])
# Out:
# 218 47.29
# 215 12.96
# 393 1.16
# 430 52.48
# 459 4.81
# 206 29.5
# 301 2.21
# 108 48.78
